# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import subprocess
import scipy as sc
from itertools import product

mpl.rcParams.update({
    "text.usetex": True,
    "font.family": "serif",
    "axes.labelsize": 12,
    "font.size": 12,
    "legend.fontsize": 10,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "figure.figsize": (4, 3.5),
    "text.latex.preamble": "\n".join([
        r"\usepackage[utf8]{inputenc}",
        r"\usepackage[T1]{fontenc}",
        r"\usepackage[detect-all,locale=FR]{siunitx}",
    ]),
    'lines.markersize': 10,
    'lines.color': 'grey',
    'scatter.marker': '+',
    'errorbar.capsize': 3,
    'savefig.bbox': 'tight',
})

# %%
path = '../'
executable = 'bin/ex2'
export_path = path + 'rapport/figures/'
data_path = 'data/'
config_path = 'bin/'
config_name = 'retraction'
config_ext = '.conf'

# %%
def stringify_dict(d: dict, sep=',') -> str:
    return sep.join(map(lambda a: str(a[0]) + "=" + str(a[1]), tuple(d.items())))

# %%
def run(config_file: str, output_file: str, params: dict = {}) -> None:
    # print(f"Running with config file {config_file}")
    options = stringify_dict(params, sep=' ')
    cmd = f"{path}{executable} {path}{config_file} output='{path}{output_file}' {options}"
    print(f"Running command `{cmd}`")
    subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL)
    # print("Done")

# %%
# nsteps = np.array([*range(500, 2001, 100)])
dts = np.linspace(1/1000, 1/10000, 20)
nsteps = 1/dts
nsimul = len(nsteps)  # Number of simulations to perform

conf = {}
with open(path + config_path + config_name + config_ext, 'r') as f:
    lines = f.read().split('\n')

for line in lines:
    if not line:
        continue
    name, _, val, *_ = line.split(' ')
    name = name.strip()
    val = val.strip()
    try:
        conf[name] = float(val)
    except ValueError:
        conf[name] = val

# Vérfier bon tFin
assert 0.96 * conf['L'] / abs(conf['alpha']) == conf['tFin']
dt = conf['tFin'] / nsteps

# %%
# %%bash
# cd .. && make clean && make
# Out:
# clang++ -o bin/ex2 src/Ex2_2024_student.cpp -std=c++17 -Wall -Wextra -O2

# %%
params_variations = {
    'nsteps': nsteps,
}
all_params = tuple(
    {a: b for a, b in zip(params_variations.keys(), c)} for c in product(*params_variations.values())
)

# Run simulations
outputs = []  # List to store output file names
for params in all_params:
    output_file = f"{data_path}{config_name},{stringify_dict(params)}.out"
    outputs.append(output_file)
    run(f'{config_path}{config_name}{config_ext}', output_file, params)
# Out:
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1000.0.out' nsteps=1000.0`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1049.7237569060774.out' nsteps=1049.7237569060774`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1104.6511627906975.out' nsteps=1104.6511627906975`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1165.644171779141.out' nsteps=1165.644171779141`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1233.7662337662339.out' nsteps=1233.7662337662339`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1310.344827586207.out' nsteps=1310.344827586207`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1397.0588235294117.out' nsteps=1397.0588235294117`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1496.0629921259842.out' nsteps=1496.0629921259842`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1610.1694915254238.out' nsteps=1610.1694915254238`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1743.1192660550457.out' nsteps=1743.1192660550457`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=1900.0.out' nsteps=1900.0`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=2087.912087912088.out' nsteps=2087.912087912088`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=2317.0731707317073.out' nsteps=2317.0731707317073`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=2602.739726027397.out' nsteps=2602.739726027397`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=2968.7500000000005.out' nsteps=2968.7500000000005`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=3454.545454545455.out' nsteps=3454.545454545455`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=4130.434782608696.out' nsteps=4130.434782608696`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=5135.135135135135.out' nsteps=5135.135135135135`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=6785.714285714284.out' nsteps=6785.714285714284`
# Running command `../bin/ex2 ../bin/retraction.conf output='../data/retraction,nsteps=10000.0.out' nsteps=10000.0`

# %%
# Load stuff in memory
all_data = {}

for file, params in zip(outputs, all_params):
    data = np.loadtxt(path + file)
    all_data[file] = (params, np.copy(data))

# %% [markdown]
# # Plots!

# %%
# %matplotlib inline
for (params, data) in all_data.values():
    if params['nsteps'] > 1000:
        continue
    t, theta, thetadot, l = data[:,0], data[:,1], data[:,2], data[:,5]
    # x = l * np.sin(theta)
    # y = -l * np.cos(theta)
    # plt.plot(x,y)
    plt.plot(t, theta)

# %%
# %matplotlib inline
plt.close()
tfin = conf['tFin']
cache = [len(all_data)-1]
colors = mpl.colormaps['rainbow'](np.linspace(0.2, 1, len(all_data)))
for i,  (params, data) in enumerate(all_data.values()):
    if i in cache:
        t, theta, thetadot = data[:,0], data[:,1], data[:,2]
        plt.plot(theta, thetadot, label=f"$\\Delta t={(tfin/params['nsteps']):.5f}$")

# plt.axis('equal')
plt.xlabel(r'$\theta$ [rad]')
plt.ylabel(r'$\dot{\theta}$ [rad/s]')
# plt.legend()
plt.grid()
plt.savefig(export_path + 'phase_retraction.pdf')

# %%
# %matplotlib inline
# plt.close()
tfin = conf['tFin']
cache = [len(all_data)-1]
colors = mpl.colormaps['rainbow'](np.linspace(0.2, 1, len(all_data)))
for i,  (params, data) in enumerate(all_data.values()):
    if i in cache:
        t, theta, thetadot = data[:,0], data[:,1], data[:,2]
        plt.plot(t, theta, label=f"$\\Delta t={(tfin/params['nsteps']):.5f}$")

# plt.axis('equal')
plt.xlabel(r'$t$ [s]')
plt.ylabel(r'$\theta$ [rad]')
# plt.legend()
plt.grid()
plt.savefig(export_path + 'traj_retraction.pdf')

# %%
def calc(dataset: dict):
    stuffies = []
    for i, (params, data) in enumerate(dataset.values()):
        tf, thetaf = data[:, 0], data[-1, 1]
        stuffies.append(thetaf)
    return stuffies

norder = 2
stuff = calc(all_data)

coefs = np.polyfit(dt**norder, stuff, 1)
fitfunc = np.poly1d(coefs)
print(fitfunc(0))

plt.plot(dt**norder, stuff, '+-', label=r'$\theta$')
plt.xlabel(r'$(\Delta t)^2$ [\si{\second\squared}]')
plt.ylabel(r'$\theta$ [rad]')
plt.grid()
plt.savefig(export_path + 'converg_retraction.pdf')
# Out:
# 78.38179155153318
